# %%
from cleaning_all_data import join_all_data, data_url
from cleaning_columns import transform_4_last_columns, cleaning_summary

# %%
def main():
    final_result = join_all_data(data_url)
    summary = transform_4_last_columns(final_result)
    summary = cleaning_summary(summary)

    return summary

# %%
result = main()
result
# Out:
#                                     nombres result_1 result_2    total  \
# 0             CAVA PORTALES ALLISON VALERIA   41.707   99.928  141.635
# 1                 CUEVA ALBINO LEYDIN MIREA   37.637   85.644  123.281
# 2                  ASTO FASABI MARC ANTHONY   27.465   70.359   97.824
# 3      IGLESIAS ZEGARRA ANACLAUDIA ANGELICA   42.732   55.054   97.786
# 4           AVALOS REYES JERRY ADOLFO AARON   35.599   62.186   97.785
# ...                                     ...      ...      ...      ...
# 64230         CHOMBA SUQUILLO EDWIN BRANDON    0.000    0.000    0.000
# 64231           CORRO CRUZ CHRISTIAN ANDRES    0.000    0.000    0.000
# 64232      ORBEGOSO MOGOLLON MARZIA VALERIA    0.000    0.000    0.000
# 64233            ROJAS LUJAN ANETTE XIOMARA    0.000    0.000    0.000
# 64234            VELASQUEZ VEGA DINA ESTHER    0.000    0.000    0.000
#
#                escuela observacion                             universidad  \
# ...

# %%
result.to_csv('unt_results.csv')
